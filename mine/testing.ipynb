# %%
import SPH2 as SPH
sph = SPH.model(particle_preview=False)
sph.cloud_movie()
# Out:
# setting up SPH model...
# placing particles in sphere with uniform distribution...
# time 0: 0
# time 1: 0.04
# time 2: 0.08
# time 3: 0.12
# time 4: 0.16
# time 5: 0.2
# time 6: 0.24000000000000002
# time 7: 0.28
# time 8: 0.32
# time 9: 0.36
# time 10: 0.39999999999999997
# time 11: 0.43999999999999995
# time 12: 0.4799999999999999
# time 13: 0.5199999999999999
# time 14: 0.5599999999999999
# time 15: 0.6
# time 16: 0.64
# time 17: 0.68
# time 18: 0.7200000000000001
# time 19: 0.7600000000000001
# time 20: 0.8000000000000002
# time 21: 0.8400000000000002
# time 22: 0.8800000000000002
# time 23: 0.9200000000000003
# time 24: 0.9600000000000003
# time 25: 1.0000000000000002
# time 26: 1.0400000000000003
# time 27: 1.0800000000000003
# time 28: 1.1200000000000003
# time 29: 1.1600000000000004
# time 30: 1.2000000000000004
# time 31: 1.2400000000000004
# time 32: 1.2800000000000005
# time 33: 1.3200000000000005
# time 34: 1.3600000000000005
# time 35: 1.4000000000000006
# ...
